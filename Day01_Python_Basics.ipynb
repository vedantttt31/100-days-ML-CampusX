# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

a = np.array(4)

print(a.ndim)
print("ndim tells the dimensions")
# Out:
# 0
# ndim tells the dimensions

# %%
arr = np.array([1,43,65,7,3,4])
print(arr)
print(arr.ndim)
# Out:
# [ 1 43 65  7  3  4]
# 1

# %%
arr = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print(arr)
print(arr.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
